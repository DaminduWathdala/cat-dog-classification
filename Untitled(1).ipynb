# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x = [1,2,3,4]
y = [8,9,10,11]
plt.scatter(x,y,c = 'r')
plt.show()

# %%
#bar chart
subjects = ["Maths","Chemestry","physics","Biology"]
marks    = [60,70,55,68]
plt.bar(subjects,marks,width = 0.5)
plt.xlabel("subjects")
plt.ylabel("marks")
plt.show()
