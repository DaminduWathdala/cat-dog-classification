# %%
import pandas as pd

# %%
x = ["Damindu","Kamal"]
y = [55,99]
data = pd.DataFrame(list(zip(x,y)),columns =["Name","Marks"])
data
# Out:
#       Name  Marks
# 0  Damindu     55
# 1    Kamal     99

# %%
data2 = pd.read_csv("/home/daminduwathsala/Downloads/ecommerce_customer_churn_dataset.csv")
data2
# Out:
#         Age  Gender Country         City  Membership_Years  Login_Frequency  \
# 0      43.0    Male  France    Marseille               2.9             14.0
# 1      36.0    Male      UK   Manchester               1.6             15.0
# 2      45.0  Female  Canada    Vancouver               2.9             10.0
# 3      56.0  Female     USA     New York               2.6             10.0
# 4      35.0    Male   India        Delhi               3.1             29.0
# ...     ...     ...     ...          ...               ...              ...
# 49995  38.0  Female     USA  Los Angeles              10.0             10.0
# 49996  37.0    Male     USA      Chicago               1.4             21.0
# 49997  44.0  Female     USA      Phoenix               2.8             19.0
# 49998  41.0  Female     USA      Chicago               2.9             17.0
# 49999  56.0    Male      UK        Leeds               2.2              2.0
#
# ...

# %%
data2.info
# Out:
# <bound method DataFrame.info of         Age  Gender Country         City  Membership_Years  Login_Frequency  \
# 0      43.0    Male  France    Marseille               2.9             14.0
# 1      36.0    Male      UK   Manchester               1.6             15.0
# 2      45.0  Female  Canada    Vancouver               2.9             10.0
# 3      56.0  Female     USA     New York               2.6             10.0
# 4      35.0    Male   India        Delhi               3.1             29.0
# ...     ...     ...     ...          ...               ...              ...
# 49995  38.0  Female     USA  Los Angeles              10.0             10.0
# 49996  37.0    Male     USA      Chicago               1.4             21.0
# 49997  44.0  Female     USA      Phoenix               2.8             19.0
# 49998  41.0  Female     USA      Chicago               2.9             17.0
# 49999  56.0    Male      UK        Leeds               2.2              2.0
#
# ...

# %%
data2.describe()
# Out:
#                 Age  Membership_Years  Login_Frequency  Session_Duration_Avg  \
# count  47505.000000      50000.000000     50000.000000          46601.000000
# mean      37.802968          2.984009        11.624660             27.660754
# std       11.834668          2.059105         7.810657             10.871013
# min        5.000000          0.100000         0.000000              1.000000
# 25%       29.000000          1.400000         6.000000             19.700000
# 50%       38.000000          2.500000        11.000000             26.800000
# 75%       46.000000          4.000000        17.000000             34.700000
# max      200.000000         10.000000        46.000000             75.600000
#
#        Pages_Per_Session  Cart_Abandonment_Rate  Wishlist_Items  \
# count       47000.000000           50000.000000    46000.000000
# mean            8.737811              57.079973        4.298391
# std             3.778220              16.282723        3.189754
# ...

# %%
data2.head()
# Out:
#     Age  Gender Country        City  Membership_Years  Login_Frequency  \
# 0  43.0    Male  France   Marseille               2.9             14.0
# 1  36.0    Male      UK  Manchester               1.6             15.0
# 2  45.0  Female  Canada   Vancouver               2.9             10.0
# 3  56.0  Female     USA    New York               2.6             10.0
# 4  35.0    Male   India       Delhi               3.1             29.0
#
#    Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                  27.4                6.0                   50.6
# 1                  42.7               10.3                   37.7
# 2                  24.8                1.6                   70.9
# 3                  38.4               14.8                   41.7
# 4                  51.4                NaN                   19.1
#
#    Wishlist_Items  ...  Email_Open_Rate  Customer_Service_Calls  \
# 0             3.0  ...             17.9                     9.0
# ...

# %%
data2.tail()
# Out:
#         Age  Gender Country         City  Membership_Years  Login_Frequency  \
# 49995  38.0  Female     USA  Los Angeles              10.0             10.0
# 49996  37.0    Male     USA      Chicago               1.4             21.0
# 49997  44.0  Female     USA      Phoenix               2.8             19.0
# 49998  41.0  Female     USA      Chicago               2.9             17.0
# 49999  56.0    Male      UK        Leeds               2.2              2.0
#
#        Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 49995                  35.8                8.8                   51.2
# 49996                  32.4                9.6                   32.5
# 49997                  40.3               10.4                   50.6
# 49998                  29.9               10.1                   60.8
# 49999                  18.2                NaN                   46.0
#
#        Wishlist_Items  ...  Email_Open_Rate  Customer_Service_Calls  \
# ...

# %%
data2["Age"]
# Out:
# 0        43.0
# 1        36.0
# 2        45.0
# 3        56.0
# 4        35.0
#          ...
# 49995    38.0
# 49996    37.0
# 49997    44.0
# 49998    41.0
# 49999    56.0
# Name: Age, Length: 50000, dtype: float64

# %%
data3 = data2["Age"]

# %%
data3
# Out:
# 0        43.0
# 1        36.0
# 2        45.0
# 3        56.0
# 4        35.0
#          ...
# 49995    38.0
# 49996    37.0
# 49997    44.0
# 49998    41.0
# 49999    56.0
# Name: Age, Length: 50000, dtype: float64

# %%
data2[["Age","Country"]]
# Out:
#         Age Country
# 0      43.0  France
# 1      36.0      UK
# 2      45.0  Canada
# 3      56.0     USA
# 4      35.0   India
# ...     ...     ...
# 49995  38.0     USA
# 49996  37.0     USA
# 49997  44.0     USA
# 49998  41.0     USA
# 49999  56.0      UK
#
# [50000 rows x 2 columns]

# %%
data2.iloc[0:3]
# Out:
#     Age  Gender Country        City  Membership_Years  Login_Frequency  \
# 0  43.0    Male  France   Marseille               2.9             14.0
# 1  36.0    Male      UK  Manchester               1.6             15.0
# 2  45.0  Female  Canada   Vancouver               2.9             10.0
#
#    Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# 0                  27.4                6.0                   50.6
# 1                  42.7               10.3                   37.7
# 2                  24.8                1.6                   70.9
#
#    Wishlist_Items  ...  Email_Open_Rate  Customer_Service_Calls  \
# 0             3.0  ...             17.9                     9.0
# 1             1.0  ...             42.8                     7.0
# 2             1.0  ...              0.0                     4.0
#
#    Product_Reviews_Written  Social_Media_Engagement_Score  Mobile_App_Usage  \
# ...

# %%
data2.iloc[0:20]
# Out:
#      Age  Gender    Country         City  Membership_Years  Login_Frequency  \
# 0   43.0    Male     France    Marseille               2.9             14.0
# 1   36.0    Male         UK   Manchester               1.6             15.0
# 2   45.0  Female     Canada    Vancouver               2.9             10.0
# 3   56.0  Female        USA     New York               2.6             10.0
# 4   35.0    Male      India        Delhi               3.1             29.0
# 5   35.0    Male      Japan        Tokyo               3.5              6.0
# 6   56.0    Male    Germany       Berlin               1.9             24.0
# 7   47.0  Female        USA      Houston               1.6             14.0
# 8   32.0    Male     Canada      Calgary               1.3             14.0
# 9   44.0    Male        USA     New York               3.6             13.0
# 10  32.0    Male         UK      Glasgow               0.9              0.0
# ...

# %%
data2.loc[1,"Age"]
# Out:
# np.float64(36.0)

# %%
#Add a column
data2["Average"] = True

# %%
data2.iloc[0:20]
# Out:
#      Age  Gender    Country         City  Membership_Years  Login_Frequency  \
# 0   43.0    Male     France    Marseille               2.9             14.0
# 1   36.0    Male         UK   Manchester               1.6             15.0
# 2   45.0  Female     Canada    Vancouver               2.9             10.0
# 3   56.0  Female        USA     New York               2.6             10.0
# 4   35.0    Male      India        Delhi               3.1             29.0
# 5   35.0    Male      Japan        Tokyo               3.5              6.0
# 6   56.0    Male    Germany       Berlin               1.9             24.0
# 7   47.0  Female        USA      Houston               1.6             14.0
# 8   32.0    Male     Canada      Calgary               1.3             14.0
# 9   44.0    Male        USA     New York               3.6             13.0
# 10  32.0    Male         UK      Glasgow               0.9              0.0
# ...

# %%
#modify values
data2["Age"] = data2["Age"] + 5

# %%
#drop column
data2.drop("Average",axis = 1,inplace= True)

# %%
#drop a row
data2.drop(0,axis=0,inplace=True)

# %%
#filter datas
data2[data2["Age"]>40]
# Out:
#         Age  Gender  Country         City  Membership_Years  Login_Frequency  \
# 1      41.0    Male       UK   Manchester               1.6             15.0
# 2      50.0  Female   Canada    Vancouver               2.9             10.0
# 3      61.0  Female      USA     New York               2.6             10.0
# 6      61.0    Male  Germany       Berlin               1.9             24.0
# 7      52.0  Female      USA      Houston               1.6             14.0
# ...     ...     ...      ...          ...               ...              ...
# 49995  43.0  Female      USA  Los Angeles              10.0             10.0
# 49996  42.0    Male      USA      Chicago               1.4             21.0
# 49997  49.0  Female      USA      Phoenix               2.8             19.0
# 49998  46.0  Female      USA      Chicago               2.9             17.0
# 49999  61.0    Male       UK        Leeds               2.2              2.0
#
# ...

# %%
#sort data
data2.sort_values("Age" , ascending = False)
# Out:
#          Age  Gender    Country         City  Membership_Years  \
# 49331  205.0    Male     France         Lyon               0.7
# 38932  205.0  Female      India      Chennai               2.7
# 22233  205.0    Male        USA      Phoenix               1.8
# 8809   205.0  Female        USA     New York               2.1
# 40909  205.0  Female        USA      Houston               1.0
# ...      ...     ...        ...          ...               ...
# 49882    NaN  Female        USA      Houston               5.4
# 49892    NaN    Male        USA  Los Angeles               5.4
# 49908    NaN    Male    Germany      Hamburg               2.5
# 49960    NaN    Male  Australia     Brisbane               5.1
# 49984    NaN  Female        USA     New York               3.3
#
#        Login_Frequency  Session_Duration_Avg  Pages_Per_Session  \
# 49331             11.0                  16.0                9.7
# 38932              0.0                   NaN                7.1
# ...

# %%
#Handle missing values
data2.isnull().sum()
# Out:
# Age                              2495
# Gender                              0
# Country                             0
# City                                0
# Membership_Years                    0
# Login_Frequency                     0
# Session_Duration_Avg             3399
# Pages_Per_Session                3000
# Cart_Abandonment_Rate               0
# Wishlist_Items                   4000
# Total_Purchases                     0
# Average_Order_Value                 0
# Days_Since_Last_Purchase         3000
# Discount_Usage_Rate              3500
# Returns_Rate                     4491
# Email_Open_Rate                  2528
# Customer_Service_Calls            168
# Product_Reviews_Written          3500
# Social_Media_Engagement_Score    6000
# Mobile_App_Usage                 5000
# Payment_Method_Diversity         2500
# Lifetime_Value                      0
# Credit_Balance                   5500
# Churned                             0
# Signup_Quarter                      0
# ...

# %%
#remove null values
data2.dropna()
# Out:
#         Age  Gender  Country      City  Membership_Years  Login_Frequency  \
# 3      61.0  Female      USA  New York               2.6             10.0
# 5      40.0    Male    Japan     Tokyo               3.5              6.0
# 6      61.0    Male  Germany    Berlin               1.9             24.0
# 10     37.0    Male       UK   Glasgow               0.9              0.0
# 11     37.0  Female  Germany    Munich               0.6             11.0
# ...     ...     ...      ...       ...               ...              ...
# 49985  45.0    Male      USA   Phoenix               4.7              6.0
# 49987  42.0  Female      USA  New York               5.4             12.0
# 49991  34.0    Male      USA   Chicago               4.9             12.0
# 49993  61.0  Female   Canada   Calgary               2.0             14.0
# 49994  23.0  Female   France      Lyon               4.8              8.0
#
#        Session_Duration_Avg  Pages_Per_Session  Cart_Abandonment_Rate  \
# ...

# %%
#replace with zero
data2.fillna(0)
# Out:
#         Age  Gender Country         City  Membership_Years  Login_Frequency  \
# 1      41.0    Male      UK   Manchester               1.6             15.0
# 2      50.0  Female  Canada    Vancouver               2.9             10.0
# 3      61.0  Female     USA     New York               2.6             10.0
# 4      40.0    Male   India        Delhi               3.1             29.0
# 5      40.0    Male   Japan        Tokyo               3.5              6.0
# ...     ...     ...     ...          ...               ...              ...
# 49995  43.0  Female     USA  Los Angeles              10.0             10.0
# 49996  42.0    Male     USA      Chicago               1.4             21.0
# 49997  49.0  Female     USA      Phoenix               2.8             19.0
# 49998  46.0  Female     USA      Chicago               2.9             17.0
# 49999  61.0    Male      UK        Leeds               2.2              2.0
#
# ...

# %%
#Group By

data2.groupby("Age")["Membership_Years"].mean()
# Out:
# Age
# 10.0     3.775000
# 15.0     2.228571
# 23.0     2.983452
# 24.0     2.846845
# 25.0     2.986801
#            ...
# 78.0     2.811111
# 79.0     2.963636
# 80.0     2.737778
# 155.0    3.344444
# 205.0    2.327273
# Name: Membership_Years, Length: 62, dtype: float64

# %%
#save data
data2.to_csv("output.csv", index=False)
